# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow import keras
from keras import layers                                                                         
from keras.layers import Conv2D,Dense,Flatten,Dropout,MaxPooling2D,BatchNormalization,Activation
from keras.models import Sequential
from keras.utils import to_categorical
from keras.regularizers import l2
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam
from keras.metrics import Recall, Accuracy,Precision
from keras.layers import DepthwiseConv2D
from PIL import Image
import seaborn as sns

# %%
import sklearn
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
(x_train,y_train),(x_test,y_test) = tf.keras.datasets.cifar10.load_data()

# %%
class_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
                'dog', 'frog', 'horse', 'ship', 'truck']

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
img = []
for label in range(len(class_labels)):
  index = (y_train == label).argmax()
  image = x_train[index]
  label = y_train[index][0]
  img.append((image,label))

# %%
plt.figure(figsize=(10,5))
for i, (image,label) in enumerate(img):
  plt.subplot(2,5,i+1)
  plt.imshow(image)
  plt.title(class_labels[label])
  plt.axis('off')

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size=0.2,random_state=30)

# %%
print('X_train Shape',x_train.shape)
print('X_test Shape',x_test.shape)
print('Y_train Shape', y_train.shape)
print('Y_test Shape', y_test.shape)
# Out:
# X_train Shape (40000, 32, 32, 3)
# X_test Shape (10000, 32, 32, 3)
# Y_train Shape (40000, 10)
# Y_test Shape (10000, 10)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 552,874
# Trainable params: 551,722
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=50,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 27s 9ms/step - loss: 1.6785 - accuracy: 0.4212 - val_loss: 1.3952 - val_accuracy: 0.5121
# Epoch 2/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.1456 - accuracy: 0.5914 - val_loss: 1.0304 - val_accuracy: 0.6408
# Epoch 3/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.9550 - accuracy: 0.6650 - val_loss: 0.8541 - val_accuracy: 0.6999
# Epoch 4/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.8505 - accuracy: 0.7041 - val_loss: 0.9506 - val_accuracy: 0.6695
# Epoch 5/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.7714 - accuracy: 0.7342 - val_loss: 0.7929 - val_accuracy: 0.7247
# Epoch 6/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.7176 - accuracy: 0.7558 - val_loss: 0.7114 - val_accuracy: 0.7599
# Epoch 7/50
# 1250/1250 [==============================] - 13s 10ms/step - loss: 0.6629 - accuracy: 0.7736 - val_loss: 0.6190 - val_accuracy: 0.7857
# Epoch 8/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.6140 - accuracy: 0.7892 - val_loss: 0.5877 - val_accuracy: 0.8041
# Epoch 9/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.5749 - accuracy: 0.8021 - val_loss: 0.5876 - val_accuracy: 0.8030
# Epoch 10/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.5447 - accuracy: 0.8151 - val_loss: 0.5612 - val_accuracy: 0.8104
# Epoch 11/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.5270 - accuracy: 0.8215 - val_loss: 0.5219 - val_accuracy: 0.8214
# Epoch 12/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4970 - accuracy: 0.8303 - val_loss: 0.5454 - val_accuracy: 0.8179
# Epoch 13/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4776 - accuracy: 0.8383 - val_loss: 0.5026 - val_accuracy: 0.8282
# Epoch 14/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4614 - accuracy: 0.8419 - val_loss: 0.5109 - val_accuracy: 0.8291
# Epoch 15/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4401 - accuracy: 0.8474 - val_loss: 0.4913 - val_accuracy: 0.8333
# Epoch 16/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4234 - accuracy: 0.8566 - val_loss: 0.4889 - val_accuracy: 0.8380
# Epoch 17/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4079 - accuracy: 0.8614 - val_loss: 0.4822 - val_accuracy: 0.8408
# Epoch 18/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4004 - accuracy: 0.8646 - val_loss: 0.5169 - val_accuracy: 0.8321
# Epoch 19/50
# 1250/1250 [==============================] - 11s 8ms/step - loss: 0.3771 - accuracy: 0.8708 - val_loss: 0.4844 - val_accuracy: 0.8419
# Epoch 20/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3692 - accuracy: 0.8731 - val_loss: 0.5009 - val_accuracy: 0.8371
# Epoch 21/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3634 - accuracy: 0.8756 - val_loss: 0.4935 - val_accuracy: 0.8430
# Epoch 22/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3478 - accuracy: 0.8811 - val_loss: 0.5171 - val_accuracy: 0.8318
# Epoch 23/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3425 - accuracy: 0.8829 - val_loss: 0.4801 - val_accuracy: 0.8462
# Epoch 24/50
# 1250/1250 [==============================] - 12s 9ms/step - loss: 0.3404 - accuracy: 0.8845 - val_loss: 0.5198 - val_accuracy: 0.8376
# Epoch 25/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3282 - accuracy: 0.8868 - val_loss: 0.4879 - val_accuracy: 0.8445
# Epoch 26/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3182 - accuracy: 0.8898 - val_loss: 0.5827 - val_accuracy: 0.8175
# Epoch 27/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3105 - accuracy: 0.8913 - val_loss: 0.5309 - val_accuracy: 0.8368
# Epoch 28/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3046 - accuracy: 0.8918 - val_loss: 0.4766 - val_accuracy: 0.8501
# Epoch 29/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2975 - accuracy: 0.8971 - val_loss: 0.4935 - val_accuracy: 0.8488
# Epoch 30/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2943 - accuracy: 0.8985 - val_loss: 0.4577 - val_accuracy: 0.8572
# Epoch 31/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2852 - accuracy: 0.9022 - val_loss: 0.5132 - val_accuracy: 0.8452
# Epoch 32/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2839 - accuracy: 0.9023 - val_loss: 0.4653 - val_accuracy: 0.8564
# Epoch 33/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2721 - accuracy: 0.9062 - val_loss: 0.4843 - val_accuracy: 0.8571
# Epoch 34/50
# 1250/1250 [==============================] - 12s 9ms/step - loss: 0.2682 - accuracy: 0.9078 - val_loss: 0.4748 - val_accuracy: 0.8531
# Epoch 35/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2683 - accuracy: 0.9076 - val_loss: 0.5055 - val_accuracy: 0.8451
# Epoch 36/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2568 - accuracy: 0.9104 - val_loss: 0.4968 - val_accuracy: 0.8495
# Epoch 37/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2534 - accuracy: 0.9114 - val_loss: 0.5079 - val_accuracy: 0.8516
# Epoch 38/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2542 - accuracy: 0.9120 - val_loss: 0.4695 - val_accuracy: 0.8524
# Epoch 39/50
# 1250/1250 [==============================] - 12s 9ms/step - loss: 0.2494 - accuracy: 0.9144 - val_loss: 0.4727 - val_accuracy: 0.8592
# Epoch 40/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2455 - accuracy: 0.9144 - val_loss: 0.4911 - val_accuracy: 0.8545
# Epoch 41/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2436 - accuracy: 0.9163 - val_loss: 0.5016 - val_accuracy: 0.8492
# Epoch 42/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2317 - accuracy: 0.9199 - val_loss: 0.5447 - val_accuracy: 0.8450
# Epoch 43/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2335 - accuracy: 0.9190 - val_loss: 0.4772 - val_accuracy: 0.8581
# Epoch 44/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2299 - accuracy: 0.9212 - val_loss: 0.4795 - val_accuracy: 0.8591
# Epoch 45/50
# 1250/1250 [==============================] - 12s 10ms/step - loss: 0.2265 - accuracy: 0.9216 - val_loss: 0.4756 - val_accuracy: 0.8612
# Epoch 46/50
# 1250/1250 [==============================] - 12s 9ms/step - loss: 0.2247 - accuracy: 0.9216 - val_loss: 0.4872 - val_accuracy: 0.8572
# Epoch 47/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2154 - accuracy: 0.9247 - val_loss: 0.5046 - val_accuracy: 0.8563
# Epoch 48/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2180 - accuracy: 0.9238 - val_loss: 0.4801 - val_accuracy: 0.8609
# Epoch 49/50
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2141 - accuracy: 0.9261 - val_loss: 0.4769 - val_accuracy: 0.8603
# Epoch 50/50
# 1250/1250 [==============================] - 12s 9ms/step - loss: 0.2174 - accuracy: 0.9248 - val_loss: 0.4860 - val_accuracy: 0.8579

# %%
evaluation = model.evaluate(x_test, y_test)
print('Test Accuracy: {}'.format(evaluation[1]))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4860 - accuracy: 0.8579
# Test Accuracy: 0.8579000234603882

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
h = model.save('weights.h5')

# %%
model.save('/content/gdrive/MyDrive/my_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
new_model = tf.keras.models.load_model('/content/gdrive/MyDrive/my_model')

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 552,874
# Trainable params: 551,722
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
loss, acc = new_model.evaluate(x_test, y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 313/313 - 1s - loss: 0.4860 - accuracy: 0.8579 - 1s/epoch - 4ms/step
# Restored model, accuracy: 85.79%

# %%
# Making the Predictions
pred = new_model.predict(x_test)
print(pred)

# Converting the predictions into label index 
pred_classes = np.argmax(pred, axis=1)
print(pred_classes)
# Out:
# 313/313 [==============================] - 1s 3ms/step
# [[5.4863012e-06 2.1438573e-06 2.1422366e-04 ... 1.6680286e-06
#   4.0659525e-06 1.2048242e-06]
#  [4.8525098e-06 2.7526392e-05 4.7319641e-11 ... 1.3608341e-11
#   9.9996746e-01 6.9317153e-08]
#  [2.2694911e-04 2.3298841e-02 4.2344677e-06 ... 9.0578618e-07
#   9.7633070e-01 1.1830196e-04]
#  ...
#  [5.1773014e-07 5.1441197e-07 9.4767551e-05 ... 1.7532225e-03
#   2.0191296e-06 2.8839295e-06]
#  [1.5094990e-04 9.9979252e-01 7.0713209e-06 ... 7.5808106e-07
#   1.2979378e-06 1.3292264e-05]
#  [6.9187607e-09 2.1805072e-07 2.3809955e-07 ... 9.9969196e-01
#   3.1063582e-10 6.1275434e-09]]
# [3 8 8 ... 5 1 7]

# %%
pred_classes.shape
# Out:
# (10000,)

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
(# Plotting the Actual vs. Predicted results

fig, axes = plt.subplots(5, 5, figsize=(15,15))
axes = axes.ravel()

for i in np.arange(0, 25):
    axes[i].imshow(x_test[i])
    axes[i].set_title("Actual: %s \nPredict: %s" % (class_labels[np.argmax(y_test[i])], class_labels[pred_classes[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)

# %%
y_true_classes = np.argmax(y_test, axis=1)

# %%
confusion_mtx = confusion_matrix(y_true_classes, pred_classes)
plt.figure(figsize=(10, 8))
plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix - CIFAR-10')
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, range(10))
plt.yticks(tick_marks, range(10))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
thresh = confusion_mtx.max() / 2.
for i in range(10):
    for j in range(10):
        plt.text(j, i, format(confusion_mtx[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if confusion_mtx[i, j] > thresh else "black")

plt.tight_layout()
plt.show()

# %%
y_test.dtype
# Out:
# dtype('float32')

# %%
from sklearn.metrics import classification_report

# Assuming you have obtained y_pred_labels and y_true_labels as mentioned before

# Generate the classification report
report = classification_report(y_true_classes, pred_classes)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      1000
#            1       0.93      0.93      0.93      1000
#            2       0.83      0.77      0.80      1000
#            3       0.80      0.67      0.73      1000
#            4       0.77      0.91      0.83      1000
#            5       0.76      0.81      0.79      1000
#            6       0.85      0.92      0.88      1000
#            7       0.92      0.88      0.90      1000
#            8       0.94      0.92      0.93      1000
#            9       0.91      0.92      0.92      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000
